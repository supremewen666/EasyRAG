# %% [markdown]
# # Query Preprocessing Lab
#
# This notebook is the stage-specific lab for this topic. It is still intentionally lightweight, but it now states the learning goal clearly so the notebook tree reads like a real curriculum instead of a list of placeholders.
#
# ## What you will do
#
# - observe how normalization, rewrite, and MQE change the effective retrieval query
# - inspect the most relevant intermediate artifacts for this stage
# - record what changed before and after the strategy you are testing
#
# ## Why this matters
#
# Preprocessing is one of the easiest places to improve recall without touching the index.

# %% [markdown]
# ## Next steps
#
# - Go to [04_01_query_modes.ipynb](04_01_query_modes.ipynb) if you want the closest prerequisite or companion walkthrough.
# - Use [06_03_retrieval_metrics.ipynb](../06_evaluation/06_03_retrieval_metrics.ipynb) as the next deeper comparison once you finish this lab.
# - Keep [notebooks/README.md](../README.md) open if you want the full stage-by-stage roadmap.
