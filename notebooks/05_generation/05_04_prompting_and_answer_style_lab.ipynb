# %% [markdown]
# # Prompting And Answer Style Lab
#
# This notebook is the stage-specific lab for this topic. It is still intentionally lightweight, but it now states the learning goal clearly so the notebook tree reads like a real curriculum instead of a list of placeholders.
#
# ## What you will do
#
# - test how extractive, abstractive, and citation-aware prompts behave over the same evidence block
# - inspect the most relevant intermediate artifacts for this stage
# - record what changed before and after the strategy you are testing
#
# ## Why this matters
#
# Prompting is easier to debug when the evidence stays fixed and only the instruction changes.

# %% [markdown]
# ## Next steps
#
# - Go to [05_03_context_packing_lab.ipynb](05_03_context_packing_lab.ipynb) if you want the closest prerequisite or companion walkthrough.
# - Use [05_05_generation_failure_cases.ipynb](05_05_generation_failure_cases.ipynb) as the next deeper comparison once you finish this lab.
# - Keep [notebooks/README.md](../README.md) open if you want the full stage-by-stage roadmap.
