# %% [markdown]
# # Top-K Selection Lab
#
# This notebook is the stage-specific lab for this topic. It is still intentionally lightweight, but it now states the learning goal clearly so the notebook tree reads like a real curriculum instead of a list of placeholders.
#
# ## What you will do
#
# - compare fixed-k, threshold-based, and budget-based evidence selection strategies
# - inspect the most relevant intermediate artifacts for this stage
# - record what changed before and after the strategy you are testing
#
# ## Why this matters
#
# The set of citations that enters generation is usually smaller than the set that retrieval first returns.

# %% [markdown]
# ## Next steps
#
# - Go to [05_01_generation_basics.ipynb](05_01_generation_basics.ipynb) if you want the closest prerequisite or companion walkthrough.
# - Use [05_03_context_packing_lab.ipynb](05_03_context_packing_lab.ipynb) as the next deeper comparison once you finish this lab.
# - Keep [notebooks/README.md](../README.md) open if you want the full stage-by-stage roadmap.
