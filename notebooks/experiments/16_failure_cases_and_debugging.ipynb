# %% [markdown]
# # Failure Cases And Debugging

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how to build intentionally bad retrieval cases for study
# - how to debug weak recall, noisy chunks, and drifting rewrites
# - how to use `QueryResult.metadata` as a teaching inspection window
