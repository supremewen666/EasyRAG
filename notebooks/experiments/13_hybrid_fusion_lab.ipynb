# %% [markdown]
# # Hybrid Fusion Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how multiple retrieval channels are merged
# - how hybrid and mix modes differ from single-channel search
# - how to observe fused rankings on the same query
