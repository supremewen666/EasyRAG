# %% [markdown]
# # Top-K Selection Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how fixed-k, threshold-based, and budget-based selection differ
# - how candidate count changes what evidence enters generation
# - how top-k for answering differs from top-k for retrieval
