# %% [markdown]
# # Rerank Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how reranking changes candidate order after recall
# - how to compare pre-rerank and post-rerank results
# - what costs and benefits reranking introduces
