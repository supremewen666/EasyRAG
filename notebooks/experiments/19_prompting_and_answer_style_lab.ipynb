# %% [markdown]
# # Prompting And Answer Style Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how prompt wording shapes grounded answer behavior
# - how extractive, abstractive, and citation-aware answers differ
# - how answer format changes interact with the same evidence set
