# %% [markdown]
# # Storage Backend Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how local and production-style backends are organized
# - how storage choices influence observability and operations
# - how to compare backend behavior without changing the main teaching API
