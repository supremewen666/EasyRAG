# %% [markdown]
# # Query Preprocessing Lab

# %% [markdown]
# Placeholder for future teaching content.
#
# This notebook will cover:
# - how normalization, rewrite, and MQE change the effective retrieval query
# - how to compare `retrieval_queries` across settings
# - how query preprocessing can improve or degrade recall
