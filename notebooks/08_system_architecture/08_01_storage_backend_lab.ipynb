# %% [markdown]
# # Storage Backend Lab
#
# This notebook is the stage-specific lab for this topic. It is still intentionally lightweight, but it now states the learning goal clearly so the notebook tree reads like a real curriculum instead of a list of placeholders.
#
# ## What you will do
#
# - compare local-first and production-style backend assumptions without changing the teaching API
# - inspect the most relevant intermediate artifacts for this stage
# - record what changed before and after the strategy you are testing
#
# ## Why this matters
#
# Backend swaps should change persistence details, not the learner's mental model of the pipeline.

# %% [markdown]
# ## Next steps
#
# - Go to [08-system-architecture-overview.md](../../docs/08-system-architecture-overview.md) if you want the closest prerequisite or companion walkthrough.
# - Use [24-local-vs-production-backends.md](../../docs/engineering/24-local-vs-production-backends.md) as the next deeper comparison once you finish this lab.
# - Keep [notebooks/README.md](../README.md) open if you want the full stage-by-stage roadmap.
